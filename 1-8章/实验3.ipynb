# %% [markdown]
# ## 练习1

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
x = np.arange(1, 11)
y = np.array([62253,51255,34541,28733,17073,9000,5963,2041,1879,1681])
y = y / 10000 # 这里需要讲解
labels = np.array(['武磊登上电影频道', '东京奥运会海报', '浓眉哥受伤', '安东尼准绝杀', '湖人单场20记盖帽', 
                   '第77届金球奖红毯', '孟非大赞武磊', '李铁上任', '活塞vs湖人', '英超'])
fig = plt.figure(figsize=(10, 6), dpi= 80)
ax = fig.add_subplot(111)
# 绘制棉棒图
markerline, stemlines, baseline = ax.stem(x, y, linefmt='--', 
                                          markerfmt='o', label='TestStem', use_line_collection=True)
# 设置棉棒图线段的属性
plt.setp(stemlines, lw=1)
ax.set_title('体育热点', fontdict={'size':18})
ax.set_ylabel('搜索指数（万）')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=60)
ax.set_ylim([0, 10])
for temp_x, temp_y in zip(x, y):
    ax.text(temp_x, temp_y + 0.5, s='{}'.format(temp_y), ha='center', va='bottom', fontsize=14)
plt.show()

# %% [markdown]
# ## 练习2

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
# 将画布划分为2×2的等分区域
fig, ax_arr = plt.subplots(2, 2, figsize=(12,8))
# 绘制华夫饼图
Waffle.make_waffle(
    ax=ax_arr[0, 0], rows=10, columns=10, 
           values=[5, 10, 85], vertical=True, colors=['r', 'g', 'b'], 
           title={'label': '高等数学复习进度'}, 
           legend={'loc': 'upper right', 'labels': ['复习完成', '正在复习', '未复习']}
)
Waffle.make_waffle(
    ax=ax_arr[0, 1], rows=10, columns=10, 
           values=[20, 30, 50], vertical=True, colors=['r', 'g', 'b'], 
           title={'label': '大学英语复习进度'}, 
           legend={'loc': 'upper right', 'labels': ['复习完成', '正在复习', '未复习']}
)
Waffle.make_waffle(
    ax=ax_arr[1, 0], rows=10, columns=10, 
           values=[80, 0, 20], vertical=True, colors=['r', 'g', 'b'], 
           title={'label': '数据可视化技术复习进度'}, 
           legend={'loc': 'upper right', 'labels': ['复习完成', '正在复习', '未复习']}
)
Waffle.make_waffle(
    ax=ax_arr[1, 1], rows=10, columns=10, 
           values=[20, 50, 30], vertical=True, colors=['r', 'g', 'b'], 
           title={'label': '大学物理复习进度'}, 
           legend={'loc': 'upper right', 'labels': ['复习完成', '正在复习', '未复习']}
)
plt.show()

# %% [markdown]
# # 练习3

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
num = 5
height = 0.5
x1 = np.array([100, 80, 70, 65, 60])    # 各环节的客户数量
x2 = np.array((x1.max() - x1) / 2)
x3 = [i + j for i, j in zip(x1, x2)]
x3 = np.array(x3)
print(x3)
y = -np.sort(-np.arange(num))               # 倒转y轴
labels=['老师讲的', '上课理解的', '课后练习的', '考前复习的', '最终得分']
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)
# 绘制条形图
rects1 = ax.barh(y, x3, height, tick_label=labels, color='g', alpha=0.5)
# 绘制辅助条形图
rects2 = ax.barh(y, x2, height, color='w', alpha=1) 
# 添加折线图
ax.plot(x3, y, 'black', alpha=0.7)
ax.plot(x2, y, 'black', alpha=0.7)
# 添加无指向型注释文本
notes = []
for i in range(0, len(x1)):
    notes.append('%.2f%%'%((x1[i] / x1[0]) * 100))
for rect_one, rect_two, note in zip(rects1, rects2, notes):
    text_x = rect_two.get_width() + (rect_one.get_width() - rect_two.get_width()) / 2 - 30
    text_y = rect_one.get_y() + height / 2
    ax.text(text_x, text_y, note, fontsize=12)
# 隐藏轴脊和刻度
ax.set_xticks([])
for direction in ['top', 'left', 'bottom', 'right']:
    ax.spines[direction].set_color('none')
ax.yaxis.set_ticks_position('none')
plt.show()
## 练习2
# Out:
# [100.   90.   85.   82.5  80. ]

# %% [markdown]
# # 练习4

# %%
import numpy as np
import matplotlib.pyplot as plt
ticks = np.array(['高等数学', '数据可视化技术', '大学物理', '大学英语', 
                  '算法分析与设计'])
y_data = np.arange(1, 6)
x_data = np.array([5, 2, 2, 1, 4])
fig,ax = plt.subplots(1, 1)
ax.barh(y_data, x_data, tick_label=ticks, left=[9, 7, 5, 4, 0], color='#CD5C5C') 
[ax.spines[i].set_visible(False) for i in ['top', 'right']]
ax.set_title("期末复习安排")
ax.set_xlabel("天数")
ax.grid(alpha=0.5, axis='x')
plt.show()
