# %% [markdown]
# # 9.2　pyecharts基础知识

# %% [markdown]
# ## 9.2.1　快速绘制图表

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
# 创建 Bar 类的对象 , 并指定画布的大小
bar = Bar(init_opts=opts.InitOpts(width='600px', height='300px' ))
# 添加 x 轴和 y 轴的数据
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# 设置标题、y 轴标签
bar.set_global_opts(title_opts=opts.TitleOpts(title="柱形图示例"),
                    yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="49c5b021135647169195adfd9651d044" style="width:600px; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_49c5b021135647169195adfd9651d044 = echarts.init(
#                     document.getElementById('49c5b021135647169195adfd9651d044'), 'white', {renderer: 'canvas'});
#                 var option_49c5b021135647169195adfd9651d044 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 5,
#                 20,
#                 36,
#                 10,
#                 75,
#                 90
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u7f8a\u6bdb\u886b",
#                 "\u96ea\u7eba\u886b",
#                 "\u88e4\u5b50",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9500\u552e\u989d(\u4e07\u5143)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u67f1\u5f62\u56fe\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_49c5b021135647169195adfd9651d044.setOption(option_49c5b021135647169195adfd9651d044);
#         });
#     </script>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
bar = (
    Bar(init_opts=opts.InitOpts(width='600px', height='300px'))
    .add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
    .set_global_opts(title_opts=opts.TitleOpts(title="柱形图示例"),
                   yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
)
bar.render()
# Out:
# 'd:\\OneDrive\\教学\\数据可视化技术\\24251\\3.程序代码\\第9章\\render.html'

# %% [markdown]
# # 9.3　绘制常用图表

# %% [markdown]
# ## 9.3.1　绘制折线图

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
line_demo = (
    Line()
    # 添加x轴、y轴的数据、系列名称
    .add_xaxis(['可乐', '雪碧', '啤酒', '橙汁', '奶茶'])
    .add_yaxis('商家A', [102, 132, 105, 52, 90], symbol='diamond', symbol_size=15)
    .add_yaxis('商家B', [86, 108, 128, 66, 136], symbol='triangle', symbol_size=15)
    # 设置标题、y 轴标签
    .set_global_opts(title_opts=opts.TitleOpts(title="饮料的销售情况折线图"), 
                   yaxis_opts=opts.AxisOpts(name="销售额(万元)",name_location="center", name_gap=30))
)
line_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="30cfccb6b23b47e5ba961835316f90d1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_30cfccb6b23b47e5ba961835316f90d1 = echarts.init(
#                     document.getElementById('30cfccb6b23b47e5ba961835316f90d1'), 'white', {renderer: 'canvas'});
#                 var option_30cfccb6b23b47e5ba961835316f90d1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "diamond",
#             "symbolSize": 15,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     102
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     132
#                 ],
#                 [
#                     "\u5564\u9152",
#                     105
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     52
#                 ],
#                 [
#                     "\u5976\u8336",
#                     90
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "triangle",
#             "symbolSize": 15,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u53ef\u4e50",
#                     86
#                 ],
#                 [
#                     "\u96ea\u78a7",
#                     108
#                 ],
#                 [
#                     "\u5564\u9152",
#                     128
#                 ],
#                 [
#                     "\u6a59\u6c41",
#                     66
#                 ],
#                 [
#                     "\u5976\u8336",
#                     136
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u53ef\u4e50",
#                 "\u96ea\u78a7",
#                 "\u5564\u9152",
#                 "\u6a59\u6c41",
#                 "\u5976\u8336"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9500\u552e\u989d(\u4e07\u5143)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u996e\u6599\u7684\u9500\u552e\u60c5\u51b5\u6298\u7ebf\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_30cfccb6b23b47e5ba961835316f90d1.setOption(option_30cfccb6b23b47e5ba961835316f90d1);
#         });
#     </script>

# %% [markdown]
# ## 9.3.2　绘制饼图或圆环图

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie
pie_demo = (
    Pie()
    .add("", [('小米', 150), ('三星', 20), ('华为', 120), ('苹果', 120), ('魅族', 117), ('vivo', 145), ('OPPO', 128)])
    .set_global_opts(title_opts=opts.TitleOpts(title="饼图示例"))
)
pie_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a3885f1719f94d0c8493bb01d831a5e7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a3885f1719f94d0c8493bb01d831a5e7 = echarts.init(
#                     document.getElementById('a3885f1719f94d0c8493bb01d831a5e7'), 'white', {renderer: 'canvas'});
#                 var option_a3885f1719f94d0c8493bb01d831a5e7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 117
#                 },
#                 {
#                     "name": "vivo",
#                     "value": 145
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 128
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "vivo",
#                 "OPPO"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u997c\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a3885f1719f94d0c8493bb01d831a5e7.setOption(option_a3885f1719f94d0c8493bb01d831a5e7);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie
pie_demo = (
    Pie()
    # 添加数据
    .add("", [('小米', 150), ('三星', 20), ('华为', 120), ('苹果', 120), ('魅族', 117), ('vivo', 145), 
              ('OPPO', 128)], center=["50%", "50%"], radius=[100, 160])
    # 设置标题
    .set_global_opts(title_opts=opts.TitleOpts(title="圆环图示例"))
)
pie_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="28e0a08b0b31453eab69106c9859fa37" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_28e0a08b0b31453eab69106c9859fa37 = echarts.init(
#                     document.getElementById('28e0a08b0b31453eab69106c9859fa37'), 'white', {renderer: 'canvas'});
#                 var option_28e0a08b0b31453eab69106c9859fa37 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": 150
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u9b45\u65cf",
#                     "value": 117
#                 },
#                 {
#                     "name": "vivo",
#                     "value": 145
#                 },
#                 {
#                     "name": "OPPO",
#                     "value": 128
#                 }
#             ],
#             "radius": [
#                 100,
#                 160
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "vivo",
#                 "OPPO"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u5706\u73af\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_28e0a08b0b31453eab69106c9859fa37.setOption(option_28e0a08b0b31453eab69106c9859fa37);
#         });
#     </script>

# %% [markdown]
# ## 9.3.3　绘制散点图

# %%
import pyecharts.options as opts
from pyecharts.charts import Scatter
scatter_demo = (
    Scatter()
    .add_xaxis(['周一', '周二', '周三', '周四', '周五', '周六', '周日'])
    .add_yaxis("", [30, 108, 73, 116, 73, 143, 106])
    # 设置标题、x 轴网格、y 轴网格和标签
    .set_global_opts(title_opts=opts.TitleOpts(title="散点图示例"), 
                   xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
                   yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True), name="用户活跃量(人)",
                                            name_location="center", name_gap=30))
)
scatter_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e259c53f381e4bc2beb8299f8f24bd45" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e259c53f381e4bc2beb8299f8f24bd45 = echarts.init(
#                     document.getElementById('e259c53f381e4bc2beb8299f8f24bd45'), 'white', {renderer: 'canvas'});
#                 var option_e259c53f381e4bc2beb8299f8f24bd45 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     30
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     108
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     73
#                 ],
#                 [
#                     "\u5468\u56db",
#                     116
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     73
#                 ],
#                 [
#                     "\u5468\u516d",
#                     143
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u7528\u6237\u6d3b\u8dc3\u91cf(\u4eba)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u6563\u70b9\u56fe\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_e259c53f381e4bc2beb8299f8f24bd45.setOption(option_e259c53f381e4bc2beb8299f8f24bd45);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import EffectScatter
effect_scatter = (
    EffectScatter()
    .add_xaxis(['周一', '周二', '周三', '周四', '周五', '周六', '周日'])
    .add_yaxis("", [30, 108, 73, 116, 73, 143, 106], symbol='pin', symbol_size=10)
    # 设置标题、x 轴网格、y 轴网格和标签
    .set_global_opts(title_opts=opts.TitleOpts(title="涟漪特效散点图示例"), 
                     xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
                     yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True), 
                                              name=" 用户活跃量(人)",name_location="center", name_gap=30)
    )
)
effect_scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c7f62e0ef72d4ef28be11e418ce77ded" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c7f62e0ef72d4ef28be11e418ce77ded = echarts.init(
#                     document.getElementById('c7f62e0ef72d4ef28be11e418ce77ded'), 'white', {renderer: 'canvas'});
#                 var option_c7f62e0ef72d4ef28be11e418ce77ded = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "legendHoverLink": true,
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "coordinateSystem": "cartesian2d",
#             "symbol": "pin",
#             "symbolSize": 10,
#             "selectedMode": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     30
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     108
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     73
#                 ],
#                 [
#                     "\u5468\u56db",
#                     116
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     73
#                 ],
#                 [
#                     "\u5468\u516d",
#                     143
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     106
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "zlevel": 0,
#             "z": 2
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5468\u4e00",
#                 "\u5468\u4e8c",
#                 "\u5468\u4e09",
#                 "\u5468\u56db",
#                 "\u5468\u4e94",
#                 "\u5468\u516d",
#                 "\u5468\u65e5"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": " \u7528\u6237\u6d3b\u8dc3\u91cf(\u4eba)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u6d9f\u6f2a\u7279\u6548\u6563\u70b9\u56fe\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_c7f62e0ef72d4ef28be11e418ce77ded.setOption(option_c7f62e0ef72d4ef28be11e418ce77ded);
#         });
#     </script>

# %% [markdown]
# ## 9.3.4　绘制3D柱形图

# %%
import random
from pyecharts import options as opts
from pyecharts.charts import Bar3D
data = [(i, j, random.randint(0, 20)) for i in range(7) for j in range(5)]
bar_3d = (
    Bar3D()
    .add("", [[d[1], d[0], d[2]] for d in data], 
         xaxis3d_opts=opts.Axis3DOpts(['A组', 'B组', 'C组','D组', 'E组'], type_="category", name=""),
         yaxis3d_opts=opts.Axis3DOpts(['周一', '周二', '周三', '周四', '周五', '周六', '周日'], type_="category", name=""),
         zaxis3d_opts=opts.Axis3DOpts(type_="value", name="销售额(万元)")
    )
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(max_=30), title_opts=opts.TitleOpts(title="3D柱形图示例")
    )
)
bar_3d.render()
# Out:
# 'd:\\OneDrive\\教学\\数据可视化技术\\24251\\3.程序代码\\第9章\\render.html'

# %% [markdown]
# ## 9.3.5　绘制统计地图

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
data_map = [['朔城区', 100], ['平鲁区', 88], ['山阴县', 99], ['应县', 68], ['右玉县', 35], ['怀仁县', 28]]
# 创建 Map 对象
map_demo = (
    Map()
    .add("商家A", data_map, "朔州")
    .set_global_opts(title_opts=opts.TitleOpts(title="朔州地图示例"), visualmap_opts=opts.VisualMapOpts())
)
map_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '朔州':'https://assets.pyecharts.org/assets/maps/shan1_xi1_shuo4_zhou1'
#         }
#     });
# </script>
#
#         <div id="303429ee35714a66a7d9356c3dff99da" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '朔州'], function(echarts) {
#                 var chart_303429ee35714a66a7d9356c3dff99da = echarts.init(
#                     document.getElementById('303429ee35714a66a7d9356c3dff99da'), 'white', {renderer: 'canvas'});
#                 var option_303429ee35714a66a7d9356c3dff99da = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u6714\u5dde",
#             "data": [
#                 {
#                     "name": "\u6714\u57ce\u533a",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u5e73\u9c81\u533a",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u5c71\u9634\u53bf",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u5e94\u53bf",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u53f3\u7389\u53bf",
#                     "value": 35
#                 },
#                 {
#                     "name": "\u6000\u4ec1\u53bf",
#                     "value": 28
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6714\u5dde\u5730\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_303429ee35714a66a7d9356c3dff99da.setOption(option_303429ee35714a66a7d9356c3dff99da);
#         });
#     </script>

# %% [markdown]
# ## 9.3.6　绘制漏斗图

# %%
from pyecharts import options as opts
from pyecharts.charts import Funnel
data_fun = [['访问商品', 100], ['加购物车', 50], ['生成订单', 30], ['支付订单', 20], ['完成交易', 15]]
# 创建 Funnel 对象
funnel_demo = (
    Funnel()
    .add("", data_fun, sort_='descending', tooltip_opts=opts.TooltipOpts(trigger="item", formatter="{a} <br/>{b} : {c}%"))
    .set_global_opts(title_opts=opts.TitleOpts(title="漏斗图示例"))
)
funnel_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7d1c45e010e24deb96629b7202464752" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7d1c45e010e24deb96629b7202464752 = echarts.init(
#                     document.getElementById('7d1c45e010e24deb96629b7202464752'), 'white', {renderer: 'canvas'});
#                 var option_7d1c45e010e24deb96629b7202464752 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "data": [
#                 {
#                     "name": "\u8bbf\u95ee\u5546\u54c1",
#                     "value": 100
#                 },
#                 {
#                     "name": "\u52a0\u8d2d\u7269\u8f66",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u751f\u6210\u8ba2\u5355",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u652f\u4ed8\u8ba2\u5355",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u5b8c\u6210\u4ea4\u6613",
#                     "value": 15
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b} : {c}%",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5b8c\u6210\u4ea4\u6613",
#                 "\u652f\u4ed8\u8ba2\u5355",
#                 "\u8bbf\u95ee\u5546\u54c1",
#                 "\u751f\u6210\u8ba2\u5355",
#                 "\u52a0\u8d2d\u7269\u8f66"
#             ],
#             "selected": {
#                 "\u8bbf\u95ee\u5546\u54c1": true,
#                 "\u52a0\u8d2d\u7269\u8f66": true,
#                 "\u751f\u6210\u8ba2\u5355": true,
#                 "\u652f\u4ed8\u8ba2\u5355": true,
#                 "\u5b8c\u6210\u4ea4\u6613": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "\u6f0f\u6597\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_7d1c45e010e24deb96629b7202464752.setOption(option_7d1c45e010e24deb96629b7202464752);
#         });
#     </script>

# %% [markdown]
# ## 9.3.7　绘制桑基图

# %%
from pyecharts import options as opts
from pyecharts.charts import Sankey
nodes = [
    {"name":"消费者"},
    {"name":"老客户"},
    {"name":"新客户"},
    {"name":"运动鞋"},
    {"name":"衬衫"},
    {"name":"连衣裙"},
    {"name":"高跟鞋"}
]
links = [
    {"source":"消费者", "target":"老客户", "value": 30},
    {"source":"消费者", "target":"新客户", "value": 20},
    {"source":"老客户", "target":"运动鞋", "value": 10},
    {"source":"老客户", "target":"衬衫", "value": 20},
    {"source":"新客户", "target":"连衣裙", "value": 10},
    {"source":"新客户", "target":"高跟鞋", "value": 10}
]
sankey_demo = (
    Sankey()
    .add("", nodes=nodes, links=links,linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
         label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="桑基图示例"))
)
sankey_demo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="03a2ac9457a34c65be2b0ebd3f24c140" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_03a2ac9457a34c65be2b0ebd3f24c140 = echarts.init(
#                     document.getElementById('03a2ac9457a34c65be2b0ebd3f24c140'), 'white', {renderer: 'canvas'});
#                 var option_03a2ac9457a34c65be2b0ebd3f24c140 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "\u6d88\u8d39\u8005"
#                 },
#                 {
#                     "name": "\u8001\u5ba2\u6237"
#                 },
#                 {
#                     "name": "\u65b0\u5ba2\u6237"
#                 },
#                 {
#                     "name": "\u8fd0\u52a8\u978b"
#                 },
#                 {
#                     "name": "\u886c\u886b"
#                 },
#                 {
#                     "name": "\u8fde\u8863\u88d9"
#                 },
#                 {
#                     "name": "\u9ad8\u8ddf\u978b"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u6d88\u8d39\u8005",
#                     "target": "\u8001\u5ba2\u6237",
#                     "value": 30
#                 },
#                 {
#                     "source": "\u6d88\u8d39\u8005",
#                     "target": "\u65b0\u5ba2\u6237",
#                     "value": 20
#                 },
#                 {
#                     "source": "\u8001\u5ba2\u6237",
#                     "target": "\u8fd0\u52a8\u978b",
#                     "value": 10
#                 },
#                 {
#                     "source": "\u8001\u5ba2\u6237",
#                     "target": "\u886c\u886b",
#                     "value": 20
#                 },
#                 {
#                     "source": "\u65b0\u5ba2\u6237",
#                     "target": "\u8fde\u8863\u88d9",
#                     "value": 10
#                 },
#                 {
#                     "source": "\u65b0\u5ba2\u6237",
#                     "target": "\u9ad8\u8ddf\u978b",
#                     "value": 10
#                 }
#             ],
#             "left": "5%",
#             "top": "5%",
#             "right": "20%",
#             "bottom": "5%",
#             "nodeWidth": 20,
#             "nodeGap": 8,
#             "nodeAlign": "justify",
#             "orient": "horizontal",
#             "draggable": true,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 0.2,
#                 "curveness": 0.5,
#                 "type": "solid",
#                 "color": "source"
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u6851\u57fa\u56fe\u793a\u4f8b",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_03a2ac9457a34c65be2b0ebd3f24c140.setOption(option_03a2ac9457a34c65be2b0ebd3f24c140);
#         });
#     </script>

# %% [markdown]
# # 9.4　绘制组合图表

# %% [markdown]
# ## 9.4.1　并行多图

# %%
# 在同一个画布上显示多个图表
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Grid
x_data = ['小米', '三星', '华为', '苹果', '魅族', 'vivo', 'OPPO']
y_a = [107, 36, 102, 91, 51, 113, 45]
y_b = [104, 60, 33, 138, 105, 111, 91]
bar = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(title_opts=opts.TitleOpts(title="组合图表-柱形图"), 
                     yaxis_opts=opts.AxisOpts(name="销售额(万元)",name_location="center", name_gap=30))
)
line = (
    Line()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="组合图表-折线图 ", pos_top="48%"),legend_opts=opts.LegendOpts(pos_top="48%"),
        yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30)
    )
)
# 创建组合图表, 并以上下布局的方式显示柱形图和折线图
grid = (
    Grid()
    .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))#从底向上60%开始，往上画
    .add(line, grid_opts=opts.GridOpts(pos_top="60%"))#从顶向下60%开始，往下画
)
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6eea32b73d614415a8ff81bbbf2d41d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6eea32b73d614415a8ff81bbbf2d41d5 = echarts.init(
#                     document.getElementById('6eea32b73d614415a8ff81bbbf2d41d5'), 'white', {renderer: 'canvas'});
#                 var option_6eea32b73d614415a8ff81bbbf2d41d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 107,
#                 36,
#                 102,
#                 91,
#                 51,
#                 113,
#                 45
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 104,
#                 60,
#                 33,
#                 138,
#                 105,
#                 111,
#                 91
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     107
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     36
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     102
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     91
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     51
#                 ],
#                 [
#                     "vivo",
#                     113
#                 ],
#                 [
#                     "OPPO",
#                     45
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     104
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     60
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     33
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     138
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     105
#                 ],
#                 [
#                     "vivo",
#                     111
#                 ],
#                 [
#                     "OPPO",
#                     91
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,

# %% [markdown]
# ## 9.4.2　顺序多图

# %%
# 在同一个网页上显示多个图表
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Page
x_data = ['小米', '三星', '华为', '苹果', '魅族', 'vivo', 'OPPO']
y_a = [107, 36, 102, 91, 51, 113, 45]
y_b = [104, 60, 33, 138, 105, 111, 91]
bar = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(title_opts=opts.TitleOpts(title="组合图表-柱形图"),
                     yaxis_opts=opts.AxisOpts(name="销售额(万元)",name_location="center", name_gap=30))
)
line = (
    Line()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(title_opts=opts.TitleOpts(title="组合图表-折线图 "),
                     yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
)
# 创建组合图表, 并在同一网页上按顺序显示柱形图和折线图
page = Page(page_title="并行多图")
page.add(bar, line)
page.render()
# Out:
# 'd:\\OneDrive\\教学\\数据可视化技术\\24251\\3.实验材料\\程序代码\\第9章\\render.html'

# %% [markdown]
# ## 9.4.3　选项卡多图

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar, Line, Tab
x_data = ['小米', '三星', '华为', '苹果', '魅族', 'vivo', 'OPPO']
y_a = [107, 36, 102, 91, 51, 113, 45]
y_b = [104, 60, 33, 138, 105, 111, 91]
bar = (
    Bar()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
)
line = (
    Line()
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
)
# 创建组合图表, 并以单击选项卡的方式显示柱形图或折线图
tab = Tab()
tab.add(bar, "柱形图")
tab.add(line, "折线图")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: block;
#         }
#
#         .chart-container:nth-child(n+2) {
#             display: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, 'aed413430f5945b2b25f2b333a37b51d')">柱形图</button>
#             <button class="tablinks" onclick="showChart(event, '03dde514451c4b59a0ffa3d55374ac4f')">折线图</button>
#     </div>
#
#         <div id="aed413430f5945b2b25f2b333a37b51d" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="03dde514451c4b59a0ffa3d55374ac4f" class="chart-container" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aed413430f5945b2b25f2b333a37b51d = echarts.init(
#                     document.getElementById('aed413430f5945b2b25f2b333a37b51d'), 'white', {renderer: 'canvas'});
#                 var option_aed413430f5945b2b25f2b333a37b51d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 107,
#                 36,
#                 102,
#                 91,
#                 51,
#                 113,
#                 45
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 104,
#                 60,
#                 33,
#                 138,
#                 105,
#                 111,
#                 91
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "vivo",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9500\u552e\u989d(\u4e07\u5143)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_aed413430f5945b2b25f2b333a37b51d.setOption(option_aed413430f5945b2b25f2b333a37b51d);
#                 var chart_03dde514451c4b59a0ffa3d55374ac4f = echarts.init(
#                     document.getElementById('03dde514451c4b59a0ffa3d55374ac4f'), 'white', {renderer: 'canvas'});
#                 var option_03dde514451c4b59a0ffa3d55374ac4f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNul

# %% [markdown]
# ## 9.4.4　时间线轮播多图

# %%
# 导入 pyecharts官方的测试数据
from pyecharts.faker import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar, Page, Pie, Timeline
# 随机获取一组测试数据
x = Faker.choose()
tl = Timeline()
for i in range(2015, 2020):
    bar = (
        Bar()
        .add_xaxis(x)
        # Faker.values() 生成一个包含7 个随机整数的列表
        .add_yaxis(" 商家 A", Faker.values())
        .add_yaxis(" 商家 B", Faker.values())
        .set_global_opts(title_opts=opts.TitleOpts("时间线轮播柱形图示例"), 
                         yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
    )
    tl.add(bar, "{}年".format(i))
tl.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="4adfede9b9514add8c344afbe859ed88" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_4adfede9b9514add8c344afbe859ed88 = echarts.init(
#                     document.getElementById('4adfede9b9514add8c344afbe859ed88'), 'white', {renderer: 'canvas'});
#                 var option_4adfede9b9514add8c344afbe859ed88 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "bar",
#                 "name": " \u5546\u5bb6 A",
#                 "legendHoverLink": true,
#                 "data": [
#                     87,
#                     60,
#                     55,
#                     52,
#                     84,
#                     71,
#                     27
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             },
#             {
#                 "type": "bar",
#                 "name": " \u5546\u5bb6 B",
#                 "legendHoverLink": true,
#                 "data": [
#                     146,
#                     71,
#                     146,
#                     71,
#                     81,
#                     137,
#                     145
#                 ],
#                 "realtimeSort": false,
#                 "showBackground": false,
#                 "stackStrategy": "samesign",
#                 "cursor": "pointer",
#                 "barMinHeight": 0,
#                 "barCategoryGap": "20%",
#                 "barGap": "30%",
#                 "large": false,
#                 "largeThreshold": 400,
#                 "seriesLayoutBy": "column",
#                 "datasetIndex": 0,
#                 "clip": true,
#                 "zlevel": 0,
#                 "z": 2,
#                 "label": {
#                     "show": true,
#                     "margin": 8
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "currentIndex": 0,
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "progress": {},
#             "data": [
#                 "2015\u5e74",
#                 "2016\u5e74",
#                 "2017\u5e74",
#                 "2018\u5e74",
#                 "2019\u5e74"
#             ]
#         },
#         "xAxis": [
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             },
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             },
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             },
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             },
#             {
#                 "show": true,
#                 "scale": false,
#                 "nameLocation": "end",
#                 "nameGap": 15,
#                 "gridIndex": 0,
#                 "inverse": false,
#                 "offset": 0,
#                 "splitNumber": 5,
#                 "minInterval": 0,
#                 "splitLine": {
#                     "show": true,
#                     "lineStyle": {
#                         "show": true,
#                         "width": 1,
#                         "opacity": 1,
#                         "curveness": 0,
#                         "type": "solid"
#                     }
#                 },
#                 "data": [
#                     "\u8349\u8393",
#                     "\u8292\u679c",
#                     "\u8461\u8404",
#                     "\u96ea\u68a8",
#                     "\u897f\u74dc",
#                     "\u67e0\u6aac",
#                     "\u8f66\u5398\u5b50"
#                 ]
#             }
#         ],
#         "yAxis": [
#             {
#                 "name": "\u9500\u552

# %% [markdown]
# # 9.5　定制图表主题

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.globals import ThemeType
x_data = ['小米', '三星', '华为', '苹果', '魅族', 'vivo', 'OPPO']
y_a = [107, 36, 102, 91, 51, 113, 45]
y_b = [104, 60, 33, 138, 105, 111, 91] 
bar = (
    # 创建 Bar 类对象 , 将图表主题替换为ThemeType.ROMA
    Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(x_data)
    .add_yaxis("商家A", y_a)
    .add_yaxis("商家B", y_b)
    .set_global_opts(title_opts=opts.TitleOpts(title="柱形图-ROMA主题"), 
                     yaxis_opts=opts.AxisOpts(name="销售额(万元)", name_location="center", name_gap=30))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'roma':'https://assets.pyecharts.org/assets/v5/themes/roma'
#         }
#     });
# </script>
#
#         <div id="1b886048b56b479a9aa8621beb158977" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'roma'], function(echarts) {
#                 var chart_1b886048b56b479a9aa8621beb158977 = echarts.init(
#                     document.getElementById('1b886048b56b479a9aa8621beb158977'), 'roma', {renderer: 'canvas'});
#                 var option_1b886048b56b479a9aa8621beb158977 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 107,
#                 36,
#                 102,
#                 91,
#                 51,
#                 113,
#                 45
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "legendHoverLink": true,
#             "data": [
#                 104,
#                 60,
#                 33,
#                 138,
#                 105,
#                 111,
#                 91
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "vivo",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "name": "\u9500\u552e\u989d(\u4e07\u5143)",
#             "show": true,
#             "scale": false,
#             "nameLocation": "center",
#             "nameGap": 30,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u67f1\u5f62\u56fe-ROMA\u4e3b\u9898",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_1b886048b56b479a9aa8621beb158977.setOption(option_1b886048b56b479a9aa8621beb158977);
#         });
#     </script>

# %% [markdown]
# # 9.7　实例：虎扑社区分析

# %%
import pyecharts.options as opts
from pyecharts.globals import ThemeType
from pyecharts.charts import Pie, Line, Map, Page
pie_hupu = (
    Pie()
    # 添加数据
    .add("", [('NBA', 232345), ('CBA', 16976), ('国际足球', 44381), 
              ('中国足球', 124), ('步行街', 512266), ('游戏电竞', 129065), 
              ('自建板块', 3805), ('运动装备', 35124), ('综合体育', 4454), 
              ('虎扑社团', 646), ('站务管理', 34467)], center=["50%", "50%"], radius=[100, 160])
    # 设置标题和图例
    .set_global_opts(title_opts=opts.TitleOpts(title=" 虎扑社区各板块发帖数"), 
                     legend_opts=opts.LegendOpts(pos_left=10, pos_top=80, orient='vertical'))
)

# %%
line_hupu = (
    Line(init_opts=opts.InitOpts(theme=ThemeType.ROMA))
    .add_xaxis(['{} : 00'.format(num) for num in range(24) if num%2 ==0])
    .add_yaxis('NBA', [259, 114, 134, 397, 840, 1577, 1413, 713, 647, 448, 462, 514], symbol='diamond', symbol_size=15)
    .add_yaxis('虎扑', [1221, 370, 359, 845, 2270, 3582, 2947, 2215, 2106, 1843, 2045, 2178], symbol='triangle',symbol_size=15)
    .set_global_opts(title_opts=opts.TitleOpts(title="虎扑社区和NBA板块24小时发帖数 "), 
                     yaxis_opts=opts.AxisOpts(name="发帖数(个)", name_location="center", name_gap=40))
)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
data_map = [['朔城区', 100], ['平鲁区', 70], ['山阴县', 68], ['应县', 40], ['右玉县', 30], ['怀仁县', 30]]
map_hupu = (
    Map()
    .add("", data_map, maptype="朔州")
    .set_global_opts(title_opts=opts.TitleOpts(title="虎扑朔州市用户地域分布"), visualmap_opts=opts.VisualMapOpts(max_=100))
)

# %%
page = Page()
page.add(pie_hupu, line_hupu, map_hupu)
page.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', '朔州':'https://assets.pyecharts.org/assets/v5/maps/shan1_xi1_shuo4_zhou1', 'roma':'https://assets.pyecharts.org/assets/v5/themes/roma'
#         }
#     });
# </script>
#
#         <div id="9b52f01202b646628a1f1d0f4cc29874" style="width:900px; height:500px;"></div>
#         <div id="8fa5d544cd804839b1b1f9b3517bf336" style="width:900px; height:500px;"></div>
#         <div id="e6509e7fb6e04e3998cb679f15c95eac" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '朔州', 'roma'], function(echarts) {
#                 var chart_9b52f01202b646628a1f1d0f4cc29874 = echarts.init(
#                     document.getElementById('9b52f01202b646628a1f1d0f4cc29874'), 'white', {renderer: 'canvas'});
#                 var option_9b52f01202b646628a1f1d0f4cc29874 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "NBA",
#                     "value": 232345
#                 },
#                 {
#                     "name": "CBA",
#                     "value": 16976
#                 },
#                 {
#                     "name": "\u56fd\u9645\u8db3\u7403",
#                     "value": 44381
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u8db3\u7403",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u6b65\u884c\u8857",
#                     "value": 512266
#                 },
#                 {
#                     "name": "\u6e38\u620f\u7535\u7ade",
#                     "value": 129065
#                 },
#                 {
#                     "name": "\u81ea\u5efa\u677f\u5757",
#                     "value": 3805
#                 },
#                 {
#                     "name": "\u8fd0\u52a8\u88c5\u5907",
#                     "value": 35124
#                 },
#                 {
#                     "name": "\u7efc\u5408\u4f53\u80b2",
#                     "value": 4454
#                 },
#                 {
#                     "name": "\u864e\u6251\u793e\u56e2",
#                     "value": 646
#                 },
#                 {
#                     "name": "\u7ad9\u52a1\u7ba1\u7406",
#                     "value": 34467
#                 }
#             ],
#             "radius": [
#                 100,
#                 160
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "NBA",
#                 "CBA",
#                 "\u56fd\u9645\u8db3\u7403",
#                 "\u4e2d\u56fd\u8db3\u7403",
#                 "\u6b65\u884c\u8857",
#                 "\u6e38\u620f\u7535\u7ade",
#                 "\u81ea\u5efa\u677f\u5757",
#                 "\u8fd0\u52a8\u88c5\u5907",
#                 "\u7efc\u5408\u4f53\u80b2",
#                 "\u864e\u6251\u793e\u56e2",
#                 "\u7ad9\u52a1\u7ba1\u7406"
#             ],
#             "selected": {},
#             "show": true,
#             "left": 10,
#             "top": 80,
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": " \u864e\u6251\u793e\u533a\u5404\u677f\u5757\u53d1\u5e16\u6570",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_9b52f01202b646628a1f1d0f4cc29874.setOption(option_9b52f01202b646628a1f1d0f4cc29874);
#                 var chart_8fa5d544cd804839b1b1f9b3517bf336 = echarts.init(
#                     document.getElementById('8fa5d544cd804839b1b1f9b3517bf336'), 'roma', {renderer: 'canvas'});
#                 var option_8fa5d544cd804839b1b1f9b3517bf336 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "NBA",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbol": "diamond",
#             "symbolSize": 15,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "stackStrategy": "samesign",
#             "data": [
#                 [
#                     "0 : 00",
#                     259
#                 ],
#                 [
#                     "2 : 00",
#                     114
#                 ],
#                 [
#                     "4 : 00",
#                     134
#                 ],
#                 [
#                     "6 : 00",
#                     397
#                 ],
#                 [
#                     "8 : 00",
#                     840
#                 ],
#                 [
#                     "10 : 00",
#                     1577
#                 ],
